# %%
from scipy.stats import kurtosis, skew

# %%
x = np.random.normal(0, 2, 10000)   # create random values based on a normal distribution
pd.Series(x).plot.density()
print( 'excess kurtosis of normal distribution (should be 0): {}'.format( kurtosis(x) ))
print( 'skewness of normal distribution (should be 0): {}'.format( skew(x) ))
# Out:
# excess kurtosis of normal distribution (should be 0): -0.024477673741567507
# skewness of normal distribution (should be 0): 0.01057235501133597

# %%
# uniform dist
x = np.random.uniform(-1,1,1000)
pd.Series(x).plot.density()
kurtosis(x), skew(x)
# Out:
# (-1.1411717443458338, 0.045842571571322197)

# %%
ser = mat1.sum(axis=1)
pd.Series(ser).plot.density()
kurtosis(ser), skew(ser)
# Out:
# (0.4432399230472237, 0.46005478734454547)

# %% [markdown]
# <img src="skewness-kurtosis_1JPG-.jpg" width=500 align='left'>

# %%
#     for i in range(0, length):
#         child = breed(pool[i], pool[len(matingpool)-i-1])
#         children.append(child)

for i in range(20):
    print(i, )
